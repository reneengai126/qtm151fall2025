# %% [markdown]
# # Assignment 6

# %% [markdown]
# <font size = "5">
#
# Import the "pandas" and "matplotlib.pyplot" libraries (and any other libraries if you would like)

# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
#
# (a) Functions
#
# <font size = "3">
#
# - Read in the dataset named "features.csv".
# - Create a ``` lambda ``` function that checks if weight $≤$ 3000
# - Using the Pandas method ``.apply()``, create a new Series that shows ``True`` if weight $≤$ 3000 and ``False``if weight > 3000.
# - Using the ``.shape`` attribute, print the number of cars that have weight $≤$ 3000.
#
# **Hint**: A Pandas Series has only one dimension, so the ``.shape`` attribute is a "tuple" with only one element. In order to get a single integer, type ``your_variable_name.shape[0]``

# %%
# Write your answer here:
features = pd.read_csv('data/features.csv')

def lambda_func(weight):
    if weight <= 3000:
        return True
    else:
        return False

weight_check = features['weight'].apply(lambda_func)
weight_check.shape[0]
print(weight_check.sum())
# Out:
# 230

# %%
features.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id
# 0  18.0          8           307        130    3504          12.0  C-1689780
# 1  15.0          8           350        165    3693          11.5  B-1689791
# 2  18.0          8           318        150    3436          11.0  P-1689802
# 3  16.0          8           304        150    3433          12.0  A-1689813
# 4  17.0          8           302        140    3449          10.5  F-1689824

# %% [markdown]
# <font size = "5">
#
# (b) Subsetting Data
#
# <font size = "3" >
#
# - Read in the dataset named "features.csv".
# - Define a global variable called ```threshold``` that takes the <br>
# value 2500
# - Subset the data to get one dataset with weight $>$ threshold and <br>
# another with weight $\le$ threshold. Use the ```.query()``` function.
# - Compute the mean acceleration for each of these datasets, printing these values to the screen<br>
#
# Note: Review how to define a global variable inside ```.query()```

# %%
# Write your answer here:
features = pd.read_csv('data/features.csv')
threshold = 2500
weight_greater = features.query("weight >= @threshold")
weight_smaller = features.query("weight <= @threshold")
weight_greater_mean = np.mean(weight_greater["acceleration"])
print("Mean of Weight>Threshold Dataset: " + str(weight_greater_mean))
weight_smaller_mean = np.mean(weight_smaller["acceleration"])
print("Mean of Weight<Threshold Dataset: " + str(weight_smaller_mean))
# Out:
# Mean of Weight>Threshold Dataset: 15.0
# Mean of Weight<Threshold Dataset: 16.53877551020408

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Read the "fifa23_players_basic.csv" dataset
# - Use ".sort_values()" to order the "Age" column <br>
# from oldest to youngest
# - Get a subset with the 5 oldest players

# %%
# Write your answer here:
fifa23_players_basic = pd.read_csv("data/fifa23_players_basic.csv")
fifa23_players_basic.sort_values(by = "Age", ascending = True)
subset_oldest = fifa23_players_basic.iloc[0:5,]
print(subset_oldest)
# Out:
#          Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions Played Best Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image Link  Age  ...  Preferred Foot  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...            Left
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...           Right
# 2  https://cdn.sofifa.net/players/188/545/23_60.png   33  ...           Right
# 3  https://cdn.sofifa.net/players/192/985/23_60.png   31  ...           Right
# 4  https://cdn.sofifa.net/players/231/747/23_60.png   23  ...           Right
#
#    Weak Foot Rating  Skill Moves  International Reputation National Team Name  \
# 0                 4            4                         5          Argentina
# 1                 4            4                         4             France
# 2                 4            4                         5             Poland
# 3                 5            4                         4            Belgium
# 4                 4            5                         4             France
#
#               National Team Image Link  National Team Position  \
# 0  https://cdn.sofifa.net/flags/ar.png                      RW
# 1  https://cdn.sofifa.net/flags/fr.png                      ST
# 2  https://cdn.sofifa.net/flags/pl.png                      ST
# 3  https://cdn.sofifa.net/flags/be.png                      RF
# 4  https://cdn.sofifa.net/flags/fr.png                      ST
#
#   National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 0                          10                 Low                 Low
# 1                          19              Medium              Medium
# 2                           9                High              Medium
# 3                           7                High                High
# 4                          10                High                 Low
#
# [5 rows x 32 columns]

# %%
fifa23_players_basic.head()
# Out:
#          Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions Played Best Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image Link  Age  ...  Preferred Foot  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...            Left
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...           Right
# 2  https://cdn.sofifa.net/players/188/545/23_60.png   33  ...           Right
# 3  https://cdn.sofifa.net/players/192/985/23_60.png   31  ...           Right
# 4  https://cdn.sofifa.net/players/231/747/23_60.png   23  ...           Right
#
#    Weak Foot Rating  Skill Moves  International Reputation National Team Name  \
# 0                 4            4                         5          Argentina
# 1                 4            4                         4             France
# 2                 4            4                         5             Poland
# 3                 5            4                         4            Belgium
# 4                 4            5                         4             France
#
#               National Team Image Link  National Team Position  \
# 0  https://cdn.sofifa.net/flags/ar.png                      RW
# 1  https://cdn.sofifa.net/flags/fr.png                      ST
# 2  https://cdn.sofifa.net/flags/pl.png                      ST
# 3  https://cdn.sofifa.net/flags/be.png                      RF
# 4  https://cdn.sofifa.net/flags/fr.png                      ST
#
#   National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 0                          10                 Low                 Low
# 1                          19              Medium              Medium
# 2                           9                High              Medium
# 3                           7                High                High
# 4                          10                High                 Low
#
# [5 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Use queries + global variables
#
# <font size = "3">
#
# - Read the "fifa23_players_basic.csv" dataset
# - Compute the mean of the column "Weight(in kg)"
# and store it as a variable
# - Subset the players whose Weight in kilograms is stricly large than this mean value
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for when using column names inside the .query() method (the backtick `)

# %%
# Write your answer here:
fifa23_players_basic = pd.read_csv("data/fifa23_players_basic.csv")
weight_mean = np.mean(fifa23_players_basic["Weight(in kg)"])
fifa23_players_basic.query("`Weight(in kg)` >= @weight_mean")
# Out:
#                 Known As                     Full Name  Overall  Potential  \
# 1             K. Benzema                 Karim Benzema       91         91
# 2         R. Lewandowski            Robert Lewandowski       91         91
# 6            T. Courtois              Thibaut Courtois       90         91
# 7               M. Neuer                  Manuel Neuer       90         90
# 8      Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro       90         90
# ...                  ...                           ...      ...        ...
# 18492          H. Tiwari                Hrithik Tiwari       49         63
# 18501      Deng Xiongtao                 Xiongtao Deng       48         61
# 18507            M. Khan            Muheet Shabir Khan       48         61
# 18508          L. Jongte            Lalbiakhlua Jongte       48         60
# 18524         A. Brînzea                Andreș Brînzea       48         72
#
#        Value(in Euro) Positions Played Best Position Nationality  \
# 1            64000000            CF,ST            CF      France
# 2            84000000               ST            ST      Poland
# 6            90000000               GK            GK     Belgium
# 7            13500000               GK            GK     Germany
# 8            41000000               ST            ST    Portugal
# ...               ...              ...           ...         ...
# 18492          100000               GK            GK       India
# 18501          100000               GK            GK    China PR
# 18507          100000               GK            GK       India
# 18508          100000               GK            GK       India
# 18524          130000               GK            GK     Romania
#
#                                              Image Link  Age  ...  \
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 6      https://cdn.sofifa.net/players/192/119/23_60.png   30  ...
# 7      https://cdn.sofifa.net/players/167/495/23_60.png   36  ...
# 8      https://cdn.sofifa.net/players/020/801/23_60.png   37  ...
# ...                                                 ...  ...  ...
# 18492  https://cdn.sofifa.net/players/265/460/23_60.png   20  ...
# 18501  https://cdn.sofifa.net/players/269/526/23_60.png   19  ...
# 18507  https://cdn.sofifa.net/players/259/562/23_60.png   20  ...
# 18508  https://cdn.sofifa.net/players/259/313/23_60.png   19  ...
# 18524  https://cdn.sofifa.net/players/271/179/23_60.png   16  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 1               Right                 4            4
# 2               Right                 4            4
# 6                Left                 3            1
# 7               Right                 4            1
# 8               Right                 4            5
# ...               ...               ...          ...
# 18492           Right                 3            1
# 18501           Right                 3            1
# 18507           Right                 2            1
# 18508            Left                 3            1
# 18524           Right                 2            1
#
#        International Reputation National Team Name  \
# 1                             4             France
# 2                             5             Poland
# 6                             4            Belgium
# 7                             5            Germany
# 8                             5           Portugal
# ...                         ...                ...
# 18492                         1                  -
# 18501                         1                  -
# 18507                         1                  -
# 18508                         1                  -
# 18524                         1                  -
#
#                   National Team Image Link  National Team Position  \
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 2      https://cdn.sofifa.net/flags/pl.png                      ST
# 6      https://cdn.sofifa.net/flags/be.png                      GK
# 7      https://cdn.sofifa.net/flags/de.png                      GK
# 8      https://cdn.sofifa.net/flags/pt.png                      ST
# ...                                    ...                     ...
# 18492                                    -                       -
# 18501                                    -                       -
# 18507                                    -                       -
# 18508                                    -                       -
# 18524  https://cdn.sofifa.net/flags/ro.png                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 1                              19              Medium              Medium
# 2                               9                High              Medium
# 6                               1              Medium              Medium
# 7                               1              Medium              Medium
# 8                               7                High                 Low
# ...                           ...                 ...                 ...
# 18492                           -              Medium              Medium
# 18501                           -              Medium              Medium
# 18507                           -              Medium              Medium
# 18508                           -              Medium              Medium
# 18524                           -              Medium              Medium
#
# [8411 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (e) Plot by Category
#
# <font size = "3">
#
# Read in the dataset named "wdi_urban.csv".
#
#   This contains data from 1980 and 2020.
#
# - **Create an array with the unique values of "year" using the ``Pandas`` function ``unique``**
#
# - **Create a plot with a ...**
#     - Histogram of "prop_urbanpopulation" (proportion of urban population) for each year
#     - Set the histogram option `alpha = 0.5` for transparency
#     - All the histograms should be overlapping on the same plot
#     - Create a legend with the list of years
#     - Label the axes and the title
#
# **Hint**: The procedure will be similar (but not exactly the same!) as when we created a scatter plot of cars with different numbers of cylinders in Lecture 11

# %%
# your answer here
wdi_urban = pd.read_csv("data/wdi_urban.csv")
years = pd.unique(wdi_urban["year"])
year = list(range(1980, 2020))
for year in years:
    subset = wdi_urban.query("year == @year")
    plt.hist(x = subset["prop_urbanpopulation"], alpha = 0.5, edgecolor = "black", label = str(year))
plt.title("Histogram of Proportion of Urban Population")
plt.xlabel("Proportion of Urban Population")
plt.ylabel("Frequency")
plt.legend()
plt.show()
